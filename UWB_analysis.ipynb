# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/Users/starsrain/2025_concord/yieldCurve_augmenting/raw_data/1028_uwbV0.csv')

# %%
print("shape:", df.shape)
print("columns:", list(df.columns))
print("\nDtypes:\n", df.dtypes)
print("\nHead:")
display(df.head(5))
print("\nNulls (top 10):")
display(df.isna().sum().sort_values(ascending=False).head(10))
# Out:
# shape: (66441, 29)
# columns: ['Application_ID', 'ApplicationDate', 'PortFolioID', 'LoanID', 'Frequency', 'LPCampaign', 'OriginatedAmount', 'OrigYear', 'OrigMonth', 'OrigWeek', 'OriginationDate', 'FPDFA', 'FPDAA', 'TotalRealizedPayin', 'InstallmentNumber', 'PaidOffPaymentAmount', 'DueDate', 'TransactionDate', 'PmtYear', 'PmtMonth', 'Days_Since_Orig', 'Weeks_Since_Orig', 'PaymentType', 'Payment_Number', 'PaymentStatus', 'weeks_between_orig_now', 'CustType', 'ProductType', 'PlanTypeName']
#
# Dtypes:
#  Application_ID              int64
# ApplicationDate            object
# PortFolioID                 int64
# LoanID                     object
# Frequency                  object
# LPCampaign                 object
# OriginatedAmount          float64
# OrigYear                  float64
# OrigMonth                 float64
# OrigWeek                  float64
# OriginationDate            object
# FPDFA                     float64
# FPDAA                     float64
# ...

# %%
df['PlanTypeName'].value_counts()
# Out:
# PlanTypeName
# Notazo default                41251
# Flat Biweekly/Semi Monthly    15980
# Flat Weekly LP                 5333
# Arrangements                   2357
# Flat Monthly LP                1520
# Name: count, dtype: int64

# %%
df_noR = pd.read_csv('/Users/starsrain/2025_concord/yieldCurve_augmenting/raw_data/1028_uwb_noR.csv')

# %%
print("shape:", df_noR.shape)
print("columns:", list(df_noR.columns))
print("\nDtypes:\n", df_noR.dtypes)
print("\nHead:")
display(df_noR.head(5))
# Out:
# shape: (39628, 29)
# columns: ['Application_ID', 'ApplicationDate', 'PortFolioID', 'LoanID', 'Frequency', 'LPCampaign', 'OriginatedAmount', 'OrigYear', 'OrigMonth', 'OrigWeek', 'OriginationDate', 'FPDFA', 'FPDAA', 'TotalRealizedPayin', 'InstallmentNumber', 'PaidOffPaymentAmount', 'DueDate', 'TransactionDate', 'PmtYear', 'PmtMonth', 'Days_Since_Orig', 'Weeks_Since_Orig', 'PaymentType', 'Payment_Number', 'PaymentStatus', 'weeks_between_orig_now', 'CustType', 'ProductType', 'PlanTypeName']
#
# Dtypes:
#  Application_ID              int64
# ApplicationDate            object
# PortFolioID                 int64
# LoanID                     object
# Frequency                  object
# LPCampaign                 object
# OriginatedAmount          float64
# OrigYear                  float64
# OrigMonth                 float64
# OrigWeek                  float64
# OriginationDate            object
# FPDFA                     float64
# FPDAA                     float64
# ...

# %%
df_noR['PlanTypeName'].value_counts()
# Out:
# PlanTypeName
# Notazo default                25634
# Flat Biweekly/Semi Monthly     8489
# Flat Weekly LP                 3670
# Flat Monthly LP                 942
# Arrangements                    893
# Name: count, dtype: int64
